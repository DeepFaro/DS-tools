# %%
from bs4 import BeautifulStoneSoup
from selenium import webdriver
import os
import logging
from seleniumwire import webdriver

# %%
chrome_driver_path = r"E:\tharhtet_git\DS-tools\scraping_tools\chromedriver\chromedriver.exe"

# %%
chrome_options = webdriver.ChromeOptions()
    
# set user agent
#chrome_options.add_argument(f'user-agent={user_agent}')
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument('--no-sandbox')
driver = webdriver.Chrome(options=chrome_options)

# %%
url = r"https://www.bbc.com/burmese/articles/cl7xwj4wdq8o"

# %%
driver.get(url)
html_content = driver.page_source

# %%
print(html_content)
# Out:
# <html lang="my" class="" dir="ltr" data-react-helmet="dir,lang"><head><meta data-react-helmet="true" http-equiv="X-UA-Compatible" content="IE=edge"><meta data-react-helmet="true" charset="utf-8"><meta data-react-helmet="true" name="robots" content="noodp, noydir, max-image-preview:large"><meta data-react-helmet="true" name="theme-color" content="#B80000"><meta data-react-helmet="true" name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"><meta data-react-helmet="true" name="apple-mobile-web-app-title" content="BBC News မြန်မာ"><meta data-react-helmet="true" name="application-name" content="BBC News မြန်မာ"><meta data-react-helmet="true" name="description" content="အရာရှိကြီးတွေ ပျောက်နေတာက မစ္စတာရှီရဲ့ခေါင်းဆောင်မှုမှာ မတည်ငြိမ်မှုလက္ခဏာတစ်ရပ်လား၊ ပိုအားကောင်းလာစေမှုလား။"><meta data-react-helmet="true" property="fb:app_id" content="1609039196070050"><meta data-react-helmet="true" name="mobile-web-app-capable" content="yes"><meta data-react-helmet="true" name=
# ...

# %%
specific_data =  html_content.find_all('#main-wrapper > div > div > div > div.bbc-1cvxiy9 > main > figure:nth-child(36) > figcaption > span > p')
print(specific_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\tharhtet_git\DS-tools\scraping_tools\web_scrpaing_sample.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/tharhtet_git/DS-tools/scraping_tools/web_scrpaing_sample.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> specific_data =  html_content.find_all('#main-wrapper > div > div > div > div.bbc-1cvxiy9 > main > figure:nth-child(36) > figcaption > span > p')
#       <a href='vscode-notebook-cell:/e%3A/tharhtet_git/DS-tools/scraping_tools/web_scrpaing_sample.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> print(specific_data)
#
# AttributeError: 'str' object has no attribute 'find_all'
